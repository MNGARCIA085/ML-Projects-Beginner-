# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import layers,callbacks,models,Sequential
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns

from sklearn.exceptions import FitFailedWarning
import warnings
warnings.simplefilter('always', FitFailedWarning)


from tensorflow import keras

# %%
seed_value = 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
#data_dir = "archive\Sports-celebrity images"
data_dir = "archive/Sports-celebrity images"
img_size=256
batch_size=32
df=tf.keras.preprocessing.image_dataset_from_directory(directory=data_dir,
                                                       shuffle=True,seed=seed_value,
                                                       image_size=(img_size,img_size),
                                                       batch_size=batch_size)
#We put the images together.
# Out:
# Found 441 files belonging to 4 classes.

# %%
def train_test_split(data,train_split=.7,val_split=.25,
                     test_split=.05,shuffle=True,shuffle_size=10000):
    
    data_size=len(data)
    if shuffle:
        data=data.shuffle(shuffle_size,seed=17)
        
    train_size=int(train_split*data_size)
    val_size=int(val_split*data_size)
    
    train_data=data.take(train_size)
    val_data=data.skip(train_size).take(val_size)
    test_data=data.skip(train_size).skip(val_size)
    
    return train_data,val_data,test_data


train_data,val_data,test_data=train_test_split(df)

# %%
test_data.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

#tf.keras.layers.RandomZoom(.5, .2)

#tf.keras.layers.RandomBrightness(
#    factor, value_range=(0, 255), seed=None, **kwargs
#) rango 0 a 1 si esta escalada


# test
train_data = train_data.map(
    lambda x, y: (data_augmentation(x, training=True), y))



train_data=train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_data=val_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data=test_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
#train_data.take(10)


for image_batch,label_batch in train_data.take(1):
    print(image_batch)


#for aux in train_data:
#    print(aux)
# Out:
# 2023-07-04 20:45:41.065871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-04 20:45:41.066437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [441]
# 	 [[{{node Placeholder/_0}}]]
# tf.Tensor(
# [[[[1.98339218e+02 2.06897537e+02 2.16686905e+02]
#    [1.51351654e+02 1.59418030e+02 1.66710541e+02]
#    [1.41098129e+02 1.48200958e+02 1.53496124e+02]
#    ...
#    [1.91076416e+02 2.14422821e+02 2.38165085e+02]
#    [1.79908508e+02 2.00407486e+02 2.15843369e+02]
#    [1.85543091e+02 2.05799316e+02 2.20472656e+02]]
#
#   [[2.05520325e+02 2.14081833e+02 2.23603836e+02]
#    [2.06524841e+02 2.15523529e+02 2.22748657e+02]
#    [1.79380264e+02 1.88087723e+02 1.93146652e+02]
#    ...
#    [1.80125992e+02 2.05275696e+02 2.22452515e+02]
#    [1.98974152e+02 2.21178253e+02 2.35033310e+02]
#    [1.93772583e+02 2.16162720e+02 2.31352966e+02]]
#
#   [[1.43752716e+02 1.45275208e+02 1.55446594e+02]
#    [1.92544998e+02 2.01068100e+02 2.08174301e+02]
#    [1.90676834e+02 1.99779465e+02 2.06663925e+02]
#    ...
#    [1.78972061e+02 2.05213165e+02 2.19729401e+02]
00000000e+00]
#    ...
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]]
#
#   [[2.00000000e+00 0.00000000e+00 1.00000000e+00]
#    [2.00000000e+00 0.00000000e+00 1.00000000e+00]
#    [2.00000000e+00 0.00000000e+00 1.00000000e+00]
#    ...
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]]
#
#   [[1.81579590e+00 1.84204102e-01 1.00000000e+00]
#    [2.00000000e+00 0.00000000e+00 1.00000000e+00]
#    [2.00000000e+00 0.00000000e+00 1.00000000e+00]
#    ...
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]
#    [0.00000000e+00 0.00000000e+00 0.00000000e+00]]]
#
#
#  [[[5.54859314e+01 7.34859314e+01 7.74859314e+01]
#    [5.42763672e+01 7.22763596e+01 7.62763596e+01]
#    [5.24495773e+01 7.04495850e+01 7.44495850e+01]
#    ...
#    [7.79391327e+01 8.69391327e+01 8.59391327e+01]
#    [6.98928528e+01 7.88928528e+01 7.78928528e+01]
#    [6.34677811e+01 7.24677811e+01 7.14677811e+01]]
#
#   [[5.58546600e+01 7.38546600e+01 7.78546600e+01]
#    [5.54019547e+01 7.34019547e+01 7.74019547e+01]
#    [5.44201126e+01 7.24201202e+01 7.64201202e+01]
#    ...
#    [7.71527023e+01 8.61527023e+01 8.51527023e+01]
#    [6.88703079e+01 7.78703079e+01 7.68703079e+01]
#    [6.07425919e+01 6.97425919e+01 6.87425919e+01]]
#
#   [[5.58370438e+01 7.39976807e+01 7.77567215e+01]
#    [5.59445267e+01 7.40254135e+01 7.79040833e+01]
#    [5.52268333e+01 7.32388077e+01 7.72208481e+01]
#    ...
#    [7.77859497e+01 8.67859497e+01 8.57859497e+01]
#    [6.88266220e+01 7.78266220e+01 7.68266220e+01]
#    [5.86826096e+01 6.76826172e+01 6.66826172e+01]]
#
#   ...
#
#   [[7.90329132e+01 8.27679520e+01 1.72623539e+01]
#    [4.11150780e+01 3.96113434e+01 3.82271729e+01]
#    [4.50928726e+01 4.60998344e+01 4.83594589e+01]
#    ...
#    [2.17252563e+02 2.16252563e+02 2.22252563e+02]
#    [2.16063660e+02 2.15151459e+02 2.20741287e+02]
#    [2.16113083e+02 2.16113083e+02 2.17392044e+02]]
#
#   [[1.07433029e+02 1.11475632e+02 2.76155052e+01]
#    [4.92477112e+01 4.92943993e+01 2.90156841e+01]
#    [3.98925247e+01 3.94337959e+01 4.45010109e+01]
#    ...
#    [2.17690109e+02 2.16690109e+02 2.22690109e+02]
#    [2.16370117e+02 2.15370117e+02 2.21370117e+02]
#    [2.16153687e+02 2.15876068e+02 2.18501190e+02]]
#
#   [[1.39813065e+02 1.44565796e+02 4.11115036e+01]
#    [6.12385788e+01 6.29680328e+01 2.24890156e+01]
#    [3.84406281e+01 3.70859985e+01 4.32857704e+01]
#    ...
#    [2.18127655e+02 2.17127655e+02 2.23127655e+02]
#    [2.16807678e+02 2.15807678e+02 2.21807678e+02]
#    [2.15963745e+02 2.15371490e+02 2.19466553e+02]]]], shape=(32, 256, 256, 3), dtype=float32)

# %%
channels=3
input_shape=(img_size,img_size,channels)

# %%
classes=df.class_names #Classes of data

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    
    x = inputs
    
    x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
    # dropout, sin batch norm
    
    
    x = layers.Dropout(0.4)(x)
    
    
    x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
    
    
    x = layers.Dropout(0.4)(x) # nuevo
    
    
    x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.AveragePooling2D(3, strides=2, padding="same")(x) 
    
    
    x = layers.Dropout(0.4)(x)
    
    
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    
    x = layers.Flatten()(x)
    
    x = layers.Dense(64,activation='relu')(x)
    
    #
    x = layers.Dropout(0.4)(x) # sin esto no anda mal pero el modelo tiene overfitting
    
    outputs = layers.Dense(units, activation=activation)(x)
    
    return keras.Model(inputs, outputs)


#model = make_model(input_shape=image_size + (3,), num_classes=4)
model = make_model(input_shape=input_shape, num_classes=4)
#keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=["accuracy"])

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20)

history=model.fit(train_data, epochs=50, verbose=1,
                  batch_size=batch_size,validation_data=val_data,callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 2023-07-04 20:45:47.713604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [441]
# 	 [[{{node Placeholder/_0}}]]
# 2023-07-04 20:45:47.714132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 9/9 [==============================] - ETA: 0s - loss: 1.5218 - accuracy: 0.2989
# 2023-07-04 20:45:54.945292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-04 20:45:54.945803: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 9/9 [==============================] - 8s 772ms/step - loss: 1.5218 - accuracy: 0.2989 - val_loss: 5.2606 - val_accuracy: 0.3125
# Epoch 2/50
# 9/9 [==============================] - 6s 674ms/step - loss: 1.3512 - accuracy: 0.3879 - val_loss: 2.7099 - val_accuracy: 0.3542
# Epoch 3/50
# 9/9 [==============================] - 6s 652ms/step - loss: 1.2065 - accuracy: 0.4306 - val_loss: 3.3961 - val_accuracy: 0.3854
# Epoch 4/50
# 9/9 [==============================] - 6s 640ms/step - loss: 1.2302 - accuracy: 0.4448 - val_loss: 2.3394 - val_accuracy: 0.4792
# Epoch 5/50
# 9/9 [==============================] - 6s 671ms/step - loss: 1.1894 - accuracy: 0.4520 - val_loss: 1.3037 - val_accuracy: 0.4479
# Epoch 6/50
# 9/9 [==============================] - 6s 709ms/step - loss: 1.1242 - accuracy: 0.5231 - val_loss: 1.8971 - val_accuracy: 0.3438
# Epoch 7/50
# 9/9 [==============================] - 6s 706ms/step - loss: 1.0553 - accuracy: 0.5658 - val_loss: 1.7263 - val_accuracy: 0.4792
# Epoch 8/50
# 9/9 [==============================] - 6s 667ms/step - loss: 0.3373 - accuracy: 0.8683 - val_loss: 0.6272 - val_accuracy: 0.7812
# Epoch 49/50
# 9/9 [==============================] - 6s 682ms/step - loss: 0.3224 - accuracy: 0.8612 - val_loss: 0.7939 - val_accuracy: 0.7396
# Epoch 50/50
# 9/9 [==============================] - 6s 665ms/step - loss: 0.2810 - accuracy: 0.8826 - val_loss: 0.8262 - val_accuracy: 0.7396

# %%
scores=model.evaluate(test_data)
# Out:
# 2023-07-04 20:51:52.669130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-04 20:51:52.669728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2/2 [==============================] - 1s 126ms/step - loss: 0.9188 - accuracy: 0.7500

# %%
history.params["epochs"]=80
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)

plt.plot(range(history.params["epochs"]),
         history.history["accuracy"],
         label="Training Accuracy")

plt.plot(range(history.params["epochs"]),
         history.history["val_accuracy"],
         label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")


plt.subplot(1,2,2)

plt.plot(range(history.params["epochs"]),
         history.history["loss"],
         label="Training Loss")

plt.plot(range(history.params["epochs"]),
         history.history["val_loss"],
         label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Training and Validation Loss")
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
#https://pub.towardsai.net/keras-tuner-tutorial-hyperparameter-optimization-tensorflow-keras-computer-vision-example-c9abbdad9887

# %% [markdown]
# # KERAS TUNER

# %%
import keras_tuner

# %%
#https://pub.towardsai.net/keras-tuner-tutorial-hyperparameter-optimization-tensorflow-keras-computer-vision-example-c9abbdad9887


from keras import backend as K


class MyHyperModel(keras_tuner.HyperModel) :
    def build(self, hp, input_shape=input_shape,num_classes=4) : 

        # Entry block
        #x = layers.Rescaling(1.0 / 255)(inputs)
        inputs = keras.Input(shape=input_shape)

        x = inputs

        x = layers.Conv2D(hp.Choice('units', [64, 128]), 3, strides=2, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)
        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
        x = layers.Dropout(0.4)(x)
        #
        x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)
        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
        x = layers.Dropout(0.4)(x) # nuevo
        #
        x = layers.Conv2D(64, 3, strides=2, padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)
        x = layers.AveragePooling2D(3, strides=2, padding="same")(x) 
        #
        x = layers.Dropout(0.4)(x)
        #
        activation = "softmax"
        units = num_classes
        #
        x = layers.Flatten()(x)
        x = layers.Dense(64,activation='relu')(x)

        #
        x = layers.Dropout(0.4)(x) # sin esto no anda mal pero el modelo tiene overfitting

        outputs = layers.Dense(units, activation=activation)(x)
        
        
        
        
        model = keras.Model(inputs=inputs, outputs=outputs)
        
        
        
        #
        # Picking an opimizer and a loss function

        model.compile(optimizer=hp.Choice('optim',['adam','adamax']),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics = ['accuracy'])
        # A way to optimize the learning rate while also trying different optimizers
        learning_rate = hp.Choice('lr', [ 0.03, 0.01, 0.003])
        K.set_value(model.optimizer.learning_rate, learning_rate)
        
        

        return model
    
    
    def fit(self, hp, model,x, *args, **kwargs) :
        return model.fit(x,*args,**kwargs)

# %%
classes = 4
hp = keras_tuner.HyperParameters()
hypermodel = MyHyperModel()
model = hypermodel.build(hp, input_shape,classes)
hypermodel.fit(hp, model, np.random.rand(4, 256, 256,3),
               np.random.rand(4, classes))
# Out:
# 2023-07-04 20:22:35.215988: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: logits and labels must have the same first dimension, got logits shape [4,4] and labels shape [16]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In [60], line 5
#       3 hypermodel = MyHyperModel()
#       4 model = hypermodel.build(hp, input_shape,classes)
# ----> 5 hypermodel.fit(hp, model, np.random.rand(4, 256, 256,3),
#       6                np.random.rand(4, classes))
#
# Cell In [58], line 69, in MyHyperModel.fit(self, hp, model, x, *args, **kwargs)
#      68 def fit(self, hp, model,x, *args, **kwargs) :
# ---> 69     return model.fit(x,*args,**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/marcos/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 982, in launch_instance
#       app.start()
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/home/marcos/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/home/marcos/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/marcos/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in run_cell
#       result = self._run_cell(
#     File "/home/marcos/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2995, in _run_cell
#       return runner(coro)
#     File "/home/marcos/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/marcos/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3194, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/marcos/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3373, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/marcos/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_7131/2055972665.py", line 5, in <module>
#       hypermodel.fit(hp, model, np.random.rand(4, 256, 256,3),
#     File "/tmp/ipykernel_7131/3276219252.py", line 69, in fit
#       return model.fit(x,*args,**kwargs)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1051, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/engine/training.py", line 1109, in compute_loss
#       return self.compiled_loss(
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/losses.py", line 142, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/losses.py", line 268, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/losses.py", line 2078, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/home/marcos/.local/lib/python3.10/site-packages/keras/backend.py", line 5660, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# logits and labels must have the same first dimension, got logits shape [4,4] and labels shape [16]
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_47835]

# %%
#https://pub.towardsai.net/keras-tuner-tutorial-hyperparameter-optimization-tensorflow-keras-computer-vision-example-c9abbdad9887

# %%
tuner = keras_tuner.BayesianOptimization(
                        hypermodel=MyHyperModel(input_shape),
                        objective = "val_accuracy",
                        max_trials =10, #max candidates to test
                        overwrite=True,
                        directory='BO_search_dir',
                        project_name='images')

# %%
# epochs defines how many epochs each candidate model
# will be trained for. The more the better, but slower.
tuner.search(x=train_data, epochs=5,
             validation_data=val_data)
# Out:
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 128               |128               |units
# adam              |adam              |optim
# 0.01              |0.01              |lr
#
# Epoch 1/5
