# %% [markdown]
# # <center> CLASIFICACIÓN DE IMÁGENES: CELEBRIDADES EN EL DEPORTE </center>

# %% [markdown]
# TABLA DE CONTENIDO

# %% [markdown]
# ## 1. Librerías necesarias

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import layers,callbacks,models,Sequential,losses
import seaborn as sns
from sklearn.metrics import confusion_matrix
import keras_tuner
from tensorflow import keras
from keras import backend as K
import os
# Out:
# 2023-07-06 15:28:02.058709: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-06 15:28:02.519930: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-06 15:28:02.521624: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 15:28:04.136832: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## 2. Carga y visualización de datos

# %%
seed_value = 57 # 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %% [markdown]
# Para cargar los datos usaremos "image_dataset_from_directory", que genera un tf.data.Dataset a partir de imágenes en un directorio. <br> <br>
# tf.data.Dataset tiene como finalidad trabajar con un conjunto potencialmente grande de elementos.
#
# <br>
# Más info: <a href="https://keras.io/api/data_loading/image/" target='_blanck'> aquí</a>

# %%
#data_dir = "archive\Sports-celebrity images"

data_dir = "archive/Sports-celebrity images"
img_size=256
batch_size=32

df=tf.keras.preprocessing.image_dataset_from_directory(directory=data_dir,
                                                       shuffle=True,
                                                       seed=seed_value,
                                                       image_size=(img_size,img_size),
                                                       batch_size=batch_size)
# Out:
# Found 441 files belonging to 4 classes.

# %% [markdown]
# Veamos alguno de los datos

# %%
for image_batch,label_batch in df.take(1):
    print(image_batch.shape)
    print(image_batch.numpy()[1])
    print(label_batch.numpy())
# Out:
# 2023-07-06 15:28:07.932299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-06 15:28:07.932744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# (32, 256, 256, 3)
# [[[1.00092834e+02 7.30928345e+01 5.40928345e+01]
#   [9.79140625e+01 7.09140625e+01 5.19140625e+01]
#   [9.74765625e+01 7.04765625e+01 5.14765625e+01]
#   ...
#   [9.81452026e+01 7.41452026e+01 6.41452026e+01]
#   [9.72785034e+01 7.42785034e+01 6.81066284e+01]
#   [9.53046875e+01 7.43046875e+01 6.93046875e+01]]
#
#  [[9.92187500e+01 7.22187500e+01 5.32187500e+01]
#   [9.68355103e+01 6.98355103e+01 5.08355103e+01]
#   [9.64356079e+01 6.94356079e+01 5.04356079e+01]
#   ...
#   [9.74356079e+01 7.34356079e+01 6.34356079e+01]
#   [9.50073853e+01 7.20073853e+01 6.58355103e+01]
#   [9.29140625e+01 7.20000000e+01 6.68281250e+01]]
#
#  [[9.81594849e+01 7.11594849e+01 5.21594849e+01]
#   [9.59140625e+01 6.89140625e+01 4.99140625e+01]
#   [9.57505493e+01 6.87505493e+01 4.97505493e+01]
#   ...
#   [9.62494507e+01 7.22494507e+01 6.22494507e+01]
#   [9.50000000e+01 7.20859375e+01 6.38281250e+01]
#   [9.30000000e+01 7.30000000e+01 6.50468750e+01]]
#
#  ...
#
#  [[3.09765625e+01 3.34062500e+01 3.24062500e+01]
#   [3.09765625e+01 3.34062500e+01 3.24062500e+01]
#   [3.09765625e+01 3.34062500e+01 3.24062500e+01]
#   ...
#   [1.00000000e+00 1.00000000e+00 1.00000000e+00]
#   [1.00000000e+00 1.00000000e+00 1.00000000e+00]
#   [1.00000000e+00 1.00000000e+00 1.00000000e+00]]
#
#  [[8.59375000e-02 4.08593750e+00 3.08593750e+00]
#   [1.91406250e+00 5.91406250e+00 4.91406250e+00]
#   [5.64392090e-01 4.56439209e+00 3.56439209e+00]
#   ...
#   [1.00000000e+00 1.00000000e+00 1.00000000e+00]
#   [1.64489746e-01 1.64489746e-01 1.83551025e+00]
#   [2.86358643e+00 6.63195801e+00 8.91046143e+00]]
#
#  [[0.00000000e+00 4.00000000e+00 3.00000000e+00]
#   [2.00000000e+00 6.00000000e+00 5.00000000e+00]
#   [5.23437500e-01 4.52343750e+00 3.52343750e+00]
#   ...
#   [1.00000000e+00 1.00000000e+00 1.00000000e+00]
#   [2.19256592e+00 3.10662842e+00 6.76287842e+00]
#   [5.13281250e+00 9.43750000e+00 1.24375000e+01]]]
# [1 1 3 1 0 1 2 2 0 3 3 3 1 3 2 2 2 0 3 3 3 3 1 2 3 2 3 1 2 0 1 2]
# 2023-07-06 15:28:08.216790: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25165824 exceeds 10% of free system memory.

# %% [markdown]
# Puede verse que:
#
# - El tamaño del lote es 32, y tiene imágenes de 256x256x3 (imágenes a color de 256x256).
# - Los valores de la imagen están entre 0 y 255
# - Las etiquetas son numéricas (con valores entre 1 y 4)

# %% [markdown]
# Definimos entonces

# %%
channels=3
input_shape=(img_size,img_size,channels)

# %% [markdown]
# Veamos los nombres de las clases y obtengamos su largo:

# %%
classes=df.class_names
print(classes)

num_classes = len(classes)
# Out:
# ['Kane Williamson', 'Kobe Bryant', 'Maria Sharapova', 'Ronaldo']

# %% [markdown]
# Finalmente imprimamos algunas imágenes:

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in df.take(1):
    for i in range(9):
        ax=plt.subplot(3,3,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(classes[label_batch[i]])
        plt.axis("off")
# Out:
# 2023-07-06 15:28:08.292144: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-06 15:28:08.292888: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-06 15:28:08.481017: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25165824 exceeds 10% of free system memory.

# %% [markdown]
# ## 3. Pre-procesamiento de datos

# %% [markdown]
# ### 3.1. División en conjuntos de entrenamiento, validación y test

# %%
def train_test_split(data,train_split=.7,val_split=.25,
                     test_split=.05,shuffle=True,shuffle_size=10000):
    
    data_size=len(data)
    if shuffle:
        data=data.shuffle(shuffle_size,seed=17)
        
    train_size=int(train_split*data_size)
    val_size=int(val_split*data_size)
    
    train_data=data.take(train_size)
    val_data=data.skip(train_size).take(val_size)
    test_data=data.skip(train_size).skip(val_size)
    
    return train_data,val_data,test_data


train_data,val_data,test_data=train_test_split(df)

# %% [markdown]
# ### 3.2. Data Augmentation

# %% [markdown]
# Como el dataset no es demasiado grande realizaremos un aumento de datos, en el que le aplicaremos transformaciones realistas a las imágenes (como rotaciones, cambio de brillo....). Esto ayuda a exponer al modelo a diferentes aspectos del conjunto de entrenamiento mientras que reduce el overfitting.

# %%
# defino las transformaciones
data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# lo aplico
train_data = train_data.map(
    lambda x, y: (data_augmentation(x, training=True), y))


# para la performance
train_data=train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_data=val_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data=test_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# Veamos cómo luce la aplicación de estas transformaciones:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_data.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# 2023-07-06 15:28:22.471711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_25' with dtype resource
# 	 [[{{node Placeholder/_25}}]]
# 2023-07-06 15:28:22.472345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-06 15:28:22.723882: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25165824 exceeds 10% of free system memory.
# 2023-07-06 15:28:22.754072: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25165824 exceeds 10% of free system memory.
# 2023-07-06 15:28:22.780094: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25165824 exceeds 10% of free system memory.

# %% [markdown]
# ## 4. Modelo

# %% [markdown]
# Comenzaremos implementando el siguiente modelo:
#
#
# IMAGEN..........................................
#
#
# <b>Nota</b> Si bien es un modelo simple que puede implementarse con la API secuencial, se hará con la funcional para tener más praćtica.

# %%
def make_model(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # escalado
    x = layers.Rescaling(1.0 / 255)(inputs)
    
    
    # capas de conv seguidas de pooling y dropout
    
    for i in range(7):
        x = layers.Conv2D(64, 3, strides=2, padding="same",activation="relu")(x)
        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
        x = layers.Dropout(0.2)(x)
   
    
    # aplano    
    x = layers.Flatten()(x)
    
    # dense y dropout
    x = layers.Dense(64,activation='relu')(x)
    #x = layers.Dropout(0.4)(x)

    
    # salida
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    
    return tf.keras.Model(inputs, outputs)

model = make_model(input_shape=input_shape, num_classes=num_classes)

# %% [markdown]
# Veamos la estructura de nuestro modelo:

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# Compilamos y ajustamos, como callbacks usaremos EarlyStoppping (para reg....) y el que guarda....

# %%
model.compile(optimizer="adam",
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=["accuracy"])


callbackss = [
    callbacks.EarlyStopping(monitor='val_loss', patience=15),
    tf.keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras",save_best_only=True),
]

history=model.fit(
                  train_data, 
                  epochs=50, 
                  verbose=1,
                  batch_size=batch_size,
                  validation_data=val_data,
                  callbacks=callbackss)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 7s 512ms/step - loss: 1.3859 - accuracy: 0.2604 - val_loss: 1.3836 - val_accuracy: 0.3021
# Epoch 2/50
# 9/9 [==============================] - 4s 480ms/step - loss: 1.3794 - accuracy: 0.2743 - val_loss: 1.3702 - val_accuracy: 0.3021
# Epoch 3/50
# 9/9 [==============================] - 4s 473ms/step - loss: 1.3797 - accuracy: 0.2743 - val_loss: 1.3766 - val_accuracy: 0.3021
# Epoch 4/50
# 9/9 [==============================] - 4s 489ms/step - loss: 1.3812 - accuracy: 0.2778 - val_loss: 1.3769 - val_accuracy: 0.3021
# Epoch 5/50
# 9/9 [==============================] - 4s 489ms/step - loss: 1.3745 - accuracy: 0.2743 - val_loss: 1.3657 - val_accuracy: 0.3125
# Epoch 6/50
# 9/9 [==============================] - 4s 494ms/step - loss: 1.3519 - accuracy: 0.3056 - val_loss: 1.3277 - val_accuracy: 0.3333
# Epoch 7/50
# 9/9 [==============================] - 4s 494ms/step - loss: 1.3588 - accuracy: 0.3715 - val_loss: 1.3148 - val_accuracy: 0.3646
# Epoch 8/50
# 9/9 [==============================] - 5s 515ms/step - loss: 1.3285 - accuracy: 0.3924 - val_loss: 1.3074 - val_accuracy: 0.4271
# Epoch 9/50
# 9/9 [==============================] - 5s 517ms/step - loss: 1.2838 - accuracy: 0.4444 - val_loss: 1.2434 - val_accuracy: 0.4375
# Epoch 10/50
# 9/9 [==============================] - 4s 480ms/step - loss: 1.2805 - accuracy: 0.4583 - val_loss: 1.3453 - val_accuracy: 0.3125
# Epoch 11/50
# 9/9 [==============================] - 4s 477ms/step - loss: 1.2377 - accuracy: 0.4514 - val_loss: 1.3331 - val_accuracy: 0.3542
# Epoch 12/50
# 9/9 [==============================] - 5s 583ms/step - loss: 1.2152 - accuracy: 0.4688 - val_loss: 1.2530 - val_accuracy: 0.3646
# Epoch 13/50
# 9/9 [==============================] - 4s 500ms/step - loss: 1.1962 - accuracy: 0.4757 - val_loss: 1.4341 - val_accuracy: 0.3125
# Epoch 14/50
# 9/9 [==============================] - 4s 493ms/step - loss: 1.1717 - accuracy: 0.4722 - val_loss: 1.2312 - val_accuracy: 0.3854
# Epoch 15/50
# 9/9 [==============================] - 4s 490ms/step - loss: 1.1732 - accuracy: 0.4965 - val_loss: 1.3411 - val_accuracy: 0.3646
# Epoch 16/50
# 9/9 [==============================] - 5s 527ms/step - loss: 1.2045 - accuracy: 0.4271 - val_loss: 1.1950 - val_accuracy: 0.4479
# Epoch 17/50
# 9/9 [==============================] - 5s 538ms/step - loss: 1.1783 - accuracy: 0.4826 - val_loss: 1.1990 - val_accuracy: 0.3958
# Epoch 18/50
# 9/9 [==============================] - 4s 498ms/step - loss: 1.1091 - accuracy: 0.4896 - val_loss: 1.3509 - val_accuracy: 0.3750
# Epoch 19/50
# 9/9 [==============================] - 4s 467ms/step - loss: 1.1011 - accuracy: 0.5174 - val_loss: 1.1687 - val_accuracy: 0.4375
# Epoch 20/50
# 9/9 [==============================] - 4s 491ms/step - loss: 1.0880 - accuracy: 0.5104 - val_loss: 1.3595 - val_accuracy: 0.3646
# Epoch 21/50
# 9/9 [==============================] - 5s 519ms/step - loss: 1.0658 - accuracy: 0.5278 - val_loss: 1.3135 - val_accuracy: 0.3750
# Epoch 22/50
# 9/9 [==============================] - 5s 527ms/step - loss: 1.0384 - accuracy: 0.5208 - val_loss: 1.1740 - val_accuracy: 0.4375
# Epoch 23/50
# 9/9 [==============================] - 4s 464ms/step - loss: 0.9685 - accuracy: 0.5660 - val_loss: 1.1483 - val_accuracy: 0.4167
# Epoch 24/50
# 9/9 [==============================] - 4s 458ms/step - loss: 1.0179 - accuracy: 0.5486 - val_loss: 1.0804 - val_accuracy: 0.5104
# Epoch 25/50
# 9/9 [==============================] - 4s 481ms/step - loss: 0.9937 - accuracy: 0.5243 - val_loss: 1.0901 - val_accuracy: 0.5000
# Epoch 26/50
# 9/9 [==============================] - 4s 472ms/step - loss: 0.9461 - accuracy: 0.5868 - val_loss: 1.2445 - val_accuracy: 0.3958
# Epoch 27/50
# 9/9 [==============================] - 4s 467ms/step - loss: 0.9731 - accuracy: 0.5694 - val_loss: 1.2316 - val_accuracy: 0.4375
# Epoch 28/50
# 9/9 [==============================] - 4s 464ms/step - loss: 0.9204 - accuracy: 0.5660 - val_loss: 1.2501 - val_accuracy: 0.4375
# Epoch 29/50
# 9/9 [==============================] - 5s 508ms/step - loss: 0.8927 - accuracy: 0.6181 - val_loss: 1.2088 - val_accuracy: 0.4688
# Epoch 30/50
# 9/9 [==============================] - 4s 490ms/step - loss: 0.8758 - accuracy: 0.6458 - val_loss: 1.0666 - val_accuracy: 0.5312
# Epoch 31/50
# 9/9 [==============================] - 4s 460ms/step - loss: 0.8765 - accuracy: 0.5972 - val_loss: 1.0556 - val_accuracy: 0.5625
# Epoch 32/50
# 9/9 [==============================] - 4s 459ms/step - loss: 0.8689 - accuracy: 0.6354 - val_loss: 1.0363 - val_accuracy: 0.5729
# Epoch 33/50
# 9/9 [==============================] - 4s 452ms/step - loss: 0.8740 - accuracy: 0.6076 - val_loss: 1.0752 - val_accuracy: 0.5521
# Epoch 34/50
# 9/9 [==============================] - 4s 459ms/step - loss: 0.8516 - accuracy: 0.6806 - val_loss: 1.1290 - val_accuracy: 0.5000
# Epoch 35/50
# 9/9 [==============================] - 4s 462ms/step - loss: 0.8035 - accuracy: 0.6701 - val_loss: 1.1035 - val_accuracy: 0.5312
# Epoch 36/50
# 9/9 [==============================] - 4s 468ms/step - loss: 0.7725 - accuracy: 0.6562 - val_loss: 1.2947 - val_accuracy: 0.5312
# Epoch 37/50
# 9/9 [==============================] - 4s 495ms/step - loss: 0.8389 - accuracy: 0.6632 - val_loss: 0.9756 - val_accuracy: 0.5625
# Epoch 38/50
# 9/9 [==============================] - 4s 496ms/step - loss: 0.7546 - accuracy: 0.6944 - val_loss: 0.9789 - val_accuracy: 0.5417
# Epoch 39/50
# 9/9 [==============================] - 4s 481ms/step - loss: 0.7109 - accuracy: 0.7014 - val_loss: 0.9253 - val_accuracy: 0.6042
# Epoch 40/50
# 9/9 [==============================] - 4s 455ms/step - loss: 0.7146 - accuracy: 0.6875 - val_loss: 1.0295 - val_accuracy: 0.5625
# Epoch 41/50
# 9/9 [==============================] - 4s 455ms/step - loss: 0.6600 - accuracy: 0.7431 - val_loss: 0.9299 - val_accuracy: 0.6458
# Epoch 42/50
# 9/9 [==============================] - 4s 470ms/step - loss: 0.6893 - accuracy: 0.7326 - val_loss: 1.1578 - val_accuracy: 0.5729
# Epoch 43/50
# 9/9 [==============================] - 4s 463ms/step - loss: 0.6452 - accuracy: 0.7188 - val_loss: 1.0659 - val_accuracy: 0.5833
# Epoch 44/50
# 9/9 [==============================] - 4s 451ms/step - loss: 0.6519 - accuracy: 0.7292 - val_loss: 0.9400 - val_accuracy: 0.6458
# Epoch 45/50
# 9/9 [==============================] - 4s 460ms/step - loss: 0.6344 - accuracy: 0.7326 - val_loss: 1.0533 - val_accuracy: 0.6354
# Epoch 46/50
# 9/9 [==============================] - 4s 454ms/step - loss: 0.7259 - accuracy: 0.7153 - val_loss: 1.1750 - val_accuracy: 0.5625
# Epoch 47/50
# 9/9 [==============================] - 4s 454ms/step - loss: 0.6747 - accuracy: 0.7500 - val_loss: 1.1396 - val_accuracy: 0.5833
# Epoch 48/50
# 9/9 [==============================] - 4s 445ms/step - loss: 0.5991 - accuracy: 0.7569 - val_loss: 0.9367 - val_accuracy: 0.6667
# Epoch 49/50
# 9/9 [==============================] - 4s 458ms/step - loss: 0.6285 - accuracy: 0.7604 - val_loss: 1.1309 - val_accuracy: 0.6146
# Epoch 50/50
# 9/9 [==============================] - 4s 452ms/step - loss: 0.5474 - accuracy: 0.8021 - val_loss: 1.0388 - val_accuracy: 0.6354

# %%
scores=model.evaluate(test_data)
# Out:
# 2/2 [==============================] - 0s 131ms/step - loss: 0.8174 - accuracy: 0.6875

# %% [markdown]
# La performance no es muy buena, tendremos que ajustar el modelo.

# %% [markdown]
# Grafiquemos para ver la situación con un poco más de detalle:

# %%
history.params["epochs"]=50
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)

plt.plot(range(history.params["epochs"]),
         history.history["accuracy"],
         label="Training Accuracy")

plt.plot(range(history.params["epochs"]),
         history.history["val_accuracy"],
         label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")


plt.subplot(1,2,2)

plt.plot(range(history.params["epochs"]),
         history.history["loss"],
         label="Training Loss")

plt.plot(range(history.params["epochs"]),
         history.history["val_loss"],
         label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Training and Validation Loss")
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %% [markdown]
# Veamos también la matriz de confusión:

# %%
#https://stackoverflow.com/questions/70775762/how-to-make-a-confusion-matrix-with-keras


#y_prediction = model.predict(x_test)
#y_prediction = np.argmax (y_prediction, axis = 1)
#y_test=np.argmax(y_test, axis=1)
#Create confusion matrix and normalizes it over predicted (columns)
#result = confusion_matrix(y_test, y_prediction , normalize='pred')




actual_list=[]
pred_list=[]
for X_batch, y_batch in test_data:
    y_batch=y_batch.numpy().tolist()
    y_pred = model.predict(X_batch)
    for i in y_batch:
        actual_list.append(i)
    for j in y_pred:
        pred_list.append(np.argmax(j,axis=-1).tolist())


cm = confusion_matrix(actual_list, pred_list)
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.show()
# Out:
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 103ms/step

# %% [markdown]
# ## 5. Ajuste de hiperparámetros

# %% [markdown]
# Entre lo que podemos ajustar se encuentran:
#
# - Algoritmo de optimización
# - Tasa de aprendizaje
# - Número de capas
# - Cantidad de unidades en cada capa
# - Kernel size
# - Pool size
# - Dropout rate
# - Cantidad de epochs
# - Arquitectura de la red

# %% [markdown]
# Hay distintos métodos para intentar el ajuste, entre ellos:
#
# - GridSearch
# - RandomSearch

# %% [markdown]
# También hay herramientas que ayudan que con esta tarea, como por ejemplo:
# <a href="https://keras.io/keras_tuner/">Keras Tuner </a>, que es la que utilizaremos.

# %%
class MyHyperModel(keras_tuner.HyperModel) :
     def build(self, hp, classes=4,input_shape=input_shape):
            
            
        units = 64
        dropout_rate = hp.Choice(name="dropout_rate", values=[0.2, 0.5])
        cant_bloques = hp.Choice(name="cant_bloques", values=[4, 5, 6, 7])



        inputs = tf.keras.Input(shape=input_shape)

        # escalado
        x = layers.Rescaling(1.0 / 255)(inputs)


        # capas de conv seguidas de pooling y dropout

        for i in range(cant_bloques):
            x = layers.Conv2D(64, 3, strides=2, padding="same",activation="relu")(x)
            x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
            x = layers.Dropout(dropout_rate)(x)


        # aplano    
        x = layers.Flatten()(x)

        # dense y dropout
        x = layers.Dense(64,activation='relu')(x)

        # salida
        outputs = layers.Dense(num_classes, activation="softmax")(x)
        
        # modelo
        model = tf.keras.Model(inputs=inputs, outputs=outputs)
        
        
        # compilación y demás
        model.compile(optimizer=hp.Choice('optim',['adam','adamax']),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                      metrics = ['accuracy'])
        
        # A way to optimize the learning rate while also trying different optimizers
        learning_rate = hp.Choice('lr', [ 0.03, 0.01, 0.003])
        K.set_value(model.optimizer.learning_rate, learning_rate)
        
        return model

# %%
tuner = keras_tuner.BayesianOptimization(
                        hypermodel=MyHyperModel(),
                        objective = "val_accuracy",
                        max_trials =10, #max candidates to test
                        overwrite=True,
                        directory='BO_search_dir2',
                        project_name='sign_languagretree_cnnfdgfd')

# %%
tuner.search(x=train_data, epochs=5,
             validation_data=val_data)
# Out:
# Trial 10 Complete [00h 00m 21s]
# val_accuracy: 0.3020833432674408
#
# Best val_accuracy So Far: 0.4166666567325592
# Total elapsed time: 00h 03m 26s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary(1)
# Out:
# Results summary
# Results in BO_search_dir2/sign_languagretree_cnnfdgfd
# Showing 1 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 02 summary
# Hyperparameters:
# dropout_rate: 0.2
# cant_bloques: 6
# optim: adamax
# lr: 0.003
# Score: 0.4166666567325592

# %%
def make_model(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # escalado
    x = layers.Rescaling(1.0 / 255)(inputs)
    
    
    # capas de conv seguidas de pooling y dropout
    
    for i in range(6):
        x = layers.Conv2D(64, 3, strides=2, padding="same",activation="relu")(x)
        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
        x = layers.Dropout(0.2)(x)
   
    
    # aplano    
    x = layers.Flatten()(x)
    
    # dense y dropout
    x = layers.Dense(64,activation='relu')(x)

    # salida
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    
    return tf.keras.Model(inputs, outputs)

model = make_model(input_shape=input_shape, num_classes=num_classes)

# %%
model.compile(optimizer=tf.keras.optimizers.Adamax(0.003),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=["accuracy"])


callbackss = [
    tf.keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras",save_best_only=True),
]

history=model.fit(
                  train_data, 
                  epochs=50, 
                  verbose=1,
                  batch_size=batch_size,
                  validation_data=val_data,
                  callbacks=callbackss)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 5s 474ms/step - loss: 2.5322 - accuracy: 0.5660 - val_loss: 1.5406 - val_accuracy: 0.3542
# Epoch 2/50
# 9/9 [==============================] - 4s 440ms/step - loss: 1.1030 - accuracy: 0.5069 - val_loss: 1.2190 - val_accuracy: 0.4583
# Epoch 3/50
# 9/9 [==============================] - 4s 441ms/step - loss: 0.9876 - accuracy: 0.5174 - val_loss: 1.2729 - val_accuracy: 0.4167
# Epoch 4/50
# 9/9 [==============================] - 4s 445ms/step - loss: 0.9074 - accuracy: 0.5521 - val_loss: 1.1310 - val_accuracy: 0.4479
# Epoch 5/50
# 9/9 [==============================] - 4s 445ms/step - loss: 0.8466 - accuracy: 0.6076 - val_loss: 1.0122 - val_accuracy: 0.5000
# Epoch 6/50
# 9/9 [==============================] - 4s 483ms/step - loss: 0.7761 - accuracy: 0.6667 - val_loss: 1.1209 - val_accuracy: 0.5104
# Epoch 7/50
# 9/9 [==============================] - 4s 470ms/step - loss: 0.7018 - accuracy: 0.7222 - val_loss: 1.0265 - val_accuracy: 0.5312
# Epoch 8/50
# 9/9 [==============================] - 4s 471ms/step - loss: 0.6711 - accuracy: 0.7188 - val_loss: 0.9638 - val_accuracy: 0.5625
# Epoch 9/50
# 9/9 [==============================] - 4s 446ms/step - loss: 0.5849 - accuracy: 0.7986 - val_loss: 1.0223 - val_accuracy: 0.5729
# Epoch 10/50
# 9/9 [==============================] - 4s 507ms/step - loss: 0.5667 - accuracy: 0.7847 - val_loss: 1.0020 - val_accuracy: 0.5833
# Epoch 11/50
# 9/9 [==============================] - 5s 536ms/step - loss: 0.5273 - accuracy: 0.7951 - val_loss: 0.8980 - val_accuracy: 0.6354
# Epoch 12/50
# 9/9 [==============================] - 4s 468ms/step - loss: 0.4941 - accuracy: 0.8264 - val_loss: 0.9690 - val_accuracy: 0.6042
# Epoch 13/50
# 9/9 [==============================] - 4s 466ms/step - loss: 0.4676 - accuracy: 0.8264 - val_loss: 0.9520 - val_accuracy: 0.6146
# Epoch 14/50
# 9/9 [==============================] - 4s 494ms/step - loss: 0.4278 - accuracy: 0.8229 - val_loss: 0.8905 - val_accuracy: 0.6562
# Epoch 15/50
# 9/9 [==============================] - 4s 469ms/step - loss: 0.4238 - accuracy: 0.8542 - val_loss: 1.0791 - val_accuracy: 0.6250
# Epoch 16/50
# 9/9 [==============================] - 4s 483ms/step - loss: 0.4270 - accuracy: 0.8438 - val_loss: 1.0353 - val_accuracy: 0.6354
# Epoch 17/50
# 9/9 [==============================] - 4s 437ms/step - loss: 0.4261 - accuracy: 0.8507 - val_loss: 0.9080 - val_accuracy: 0.6771
# Epoch 18/50
# 9/9 [==============================] - 4s 438ms/step - loss: 0.3142 - accuracy: 0.9062 - val_loss: 1.0384 - val_accuracy: 0.6354
# Epoch 19/50
# 9/9 [==============================] - 4s 434ms/step - loss: 0.3436 - accuracy: 0.8750 - val_loss: 1.0339 - val_accuracy: 0.6458
# Epoch 20/50
# 9/9 [==============================] - 4s 435ms/step - loss: 0.3685 - accuracy: 0.8576 - val_loss: 1.4230 - val_accuracy: 0.5938
# Epoch 21/50
# 9/9 [==============================] - 4s 430ms/step - loss: 0.3777 - accuracy: 0.8507 - val_loss: 0.9199 - val_accuracy: 0.6979
# Epoch 22/50
# 9/9 [==============================] - 4s 433ms/step - loss: 0.3027 - accuracy: 0.8889 - val_loss: 1.0530 - val_accuracy: 0.6771
# Epoch 23/50
# 9/9 [==============================] - 4s 441ms/step - loss: 0.3021 - accuracy: 0.8958 - val_loss: 1.0399 - val_accuracy: 0.7083
# Epoch 24/50
# 9/9 [==============================] - 4s 440ms/step - loss: 0.3289 - accuracy: 0.8542 - val_loss: 1.0761 - val_accuracy: 0.7188
# Epoch 25/50
# 9/9 [==============================] - 4s 437ms/step - loss: 0.2880 - accuracy: 0.9028 - val_loss: 1.1631 - val_accuracy: 0.6771
# Epoch 26/50
# 9/9 [==============================] - 4s 437ms/step - loss: 0.3147 - accuracy: 0.8785 - val_loss: 1.1333 - val_accuracy: 0.6875
# Epoch 27/50
# 9/9 [==============================] - 4s 443ms/step - loss: 0.2662 - accuracy: 0.9028 - val_loss: 1.0380 - val_accuracy: 0.7500
# Epoch 28/50
# 9/9 [==============================] - 4s 434ms/step - loss: 0.3231 - accuracy: 0.8715 - val_loss: 1.3819 - val_accuracy: 0.6250
# Epoch 29/50
# 9/9 [==============================] - 4s 434ms/step - loss: 0.2991 - accuracy: 0.8785 - val_loss: 1.2007 - val_accuracy: 0.6562
# Epoch 30/50
# 9/9 [==============================] - 4s 440ms/step - loss: 0.2912 - accuracy: 0.8924 - val_loss: 1.0073 - val_accuracy: 0.7500
# Epoch 31/50
# 9/9 [==============================] - 4s 438ms/step - loss: 0.3601 - accuracy: 0.8715 - val_loss: 1.3556 - val_accuracy: 0.6354
# Epoch 32/50
# 9/9 [==============================] - 4s 436ms/step - loss: 0.2717 - accuracy: 0.9062 - val_loss: 1.0436 - val_accuracy: 0.7500
# Epoch 33/50
# 9/9 [==============================] - 4s 436ms/step - loss: 0.2964 - accuracy: 0.8924 - val_loss: 1.1617 - val_accuracy: 0.6875
# Epoch 34/50
# 9/9 [==============================] - 4s 439ms/step - loss: 0.2852 - accuracy: 0.8924 - val_loss: 1.0774 - val_accuracy: 0.6771
# Epoch 35/50
# 9/9 [==============================] - 4s 439ms/step - loss: 0.2512 - accuracy: 0.9167 - val_loss: 1.1629 - val_accuracy: 0.6875
# Epoch 36/50
# 9/9 [==============================] - 4s 437ms/step - loss: 0.2381 - accuracy: 0.9132 - val_loss: 1.1573 - val_accuracy: 0.6875
# Epoch 37/50
# 9/9 [==============================] - 4s 438ms/step - loss: 0.2513 - accuracy: 0.9062 - val_loss: 1.0670 - val_accuracy: 0.7188
# Epoch 38/50
# 9/9 [==============================] - 4s 432ms/step - loss: 0.2014 - accuracy: 0.9375 - val_loss: 1.0838 - val_accuracy: 0.7500
# Epoch 39/50
# 9/9 [==============================] - 4s 439ms/step - loss: 0.2819 - accuracy: 0.8958 - val_loss: 0.9325 - val_accuracy: 0.7708
# Epoch 40/50
# 9/9 [==============================] - 4s 433ms/step - loss: 0.2495 - accuracy: 0.9028 - val_loss: 1.4932 - val_accuracy: 0.6250
# Epoch 41/50
# 9/9 [==============================] - 4s 436ms/step - loss: 0.2459 - accuracy: 0.9062 - val_loss: 1.0575 - val_accuracy: 0.7396
# Epoch 42/50
# 9/9 [==============================] - 4s 436ms/step - loss: 0.2268 - accuracy: 0.9097 - val_loss: 1.1902 - val_accuracy: 0.7188
# Epoch 43/50
# 9/9 [==============================] - 4s 437ms/step - loss: 0.2503 - accuracy: 0.9062 - val_loss: 1.0295 - val_accuracy: 0.7500
# Epoch 44/50
# 9/9 [==============================] - 4s 440ms/step - loss: 0.2486 - accuracy: 0.9028 - val_loss: 1.1384 - val_accuracy: 0.7188
# Epoch 45/50
# 9/9 [==============================] - 4s 436ms/step - loss: 0.2239 - accuracy: 0.9201 - val_loss: 1.1037 - val_accuracy: 0.7396
# Epoch 46/50
# 9/9 [==============================] - 4s 433ms/step - loss: 0.2058 - accuracy: 0.9097 - val_loss: 1.1968 - val_accuracy: 0.6979
# Epoch 47/50
# 9/9 [==============================] - 4s 441ms/step - loss: 0.1929 - accuracy: 0.9340 - val_loss: 1.0899 - val_accuracy: 0.7292
# Epoch 48/50
# 9/9 [==============================] - 4s 436ms/step - loss: 0.2200 - accuracy: 0.9201 - val_loss: 1.0725 - val_accuracy: 0.7500
# Epoch 49/50
# 9/9 [==============================] - 4s 441ms/step - loss: 0.2197 - accuracy: 0.9132 - val_loss: 1.3540 - val_accuracy: 0.6875
# Epoch 50/50
# 9/9 [==============================] - 4s 438ms/step - loss: 0.1915 - accuracy: 0.9375 - val_loss: 1.0861 - val_accuracy: 0.7292

# %%
scores=model.evaluate(test_data)
# Out:
# 2/2 [==============================] - 0s 100ms/step - loss: 0.6902 - accuracy: 0.7812

# %% [markdown]
# ## 6. Predicciones con el modelo final

# %% [markdown]
# Veamos algunas predicciones con nuestras propias imágenes,

# %%
#model.predict(test_data)


# antes usé classes cuando debía ser num_classes

# %%
def predicts(model,img):
    
    #img = Image.open(img)
    #img = img.resize((256,256))
    
    
    img_array=tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array=tf.expand_dims(img_array,0)
    
    predictions=model.predict(img_array)

    
    predicted_class=classes[np.argmax(predictions[0])]
    confidence=round(100*(np.max(predictions[0])),2)
    
    return predicted_class,confidence

# %%
predicts(model,'my_test_images/maria.png')
# Out:
# 1/1 [==============================] - 0s 19ms/step
# ('Maria Sharapova', 72.93)

# %% [markdown]
# ['Kane Williamson', 'Kobe Bryant', 'Maria Sharapova', 'Ronaldo']

# %%
plt.figure(figsize=(15,15))
for images,labels in test_data.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class,confidence=predicts(model,images[i].numpy())
        actual_class=classes[labels[i]]
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class},\
                  \n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 2023-07-06 20:09:07.193530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 2023-07-06 20:09:07.194201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [441]
# 	 [[{{node Placeholder/_4}}]]
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 52ms/step

# %%
image_size = (256, 256)


img = keras.utils.load_img(
    "my_test_images/maria.png", target_size=image_size
)
img_array = keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)


print(predictions)


predictions=model.predict(img_array)

    
predicted_class=classes[np.argmax(predictions[0])]

predicted_class

#score = float(predictions[0])
#print(f"This image is {100 * (1 - score):.2f}% cat and {100 * score:.2f}% dog.")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [[0.01187599 0.08963943 0.82880473 0.06967991]]
# 1/1 [==============================] - 0s 18ms/step
# 'Maria Sharapova'

# %% [markdown]
# ## 7. Guardando el modelo
